# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('C:/Users/STAFF/Downloads/train.csv/train.csv')

# %%
data = pd.DataFrame(dataset)

# %%
data = data.dropna()

# %%
data.head(10)
# Out:
#     Age    Occupation  AnnualIncome  MonthlyInhandSalary  NumBankAccounts  \
# 6    23     Scientist      19114.12          1824.843333                2
# 9    28       Teacher      34847.84          3037.986667                1
# 12   28       Teacher      34847.84          3037.986667                1
# 13   28       Teacher      34847.84          3037.986667                2
# 15   28       Teacher      34847.84          3037.986667                2
# 17   34      Engineer     143162.64         12187.220000                3
# 21   34      Engineer     143162.64         12187.220000                2
# 22   34      Engineer     143162.64         12187.220000                3
# 23   34      Engineer     143162.64         12187.220000                2
# 24   54  Entrepreneur      30689.89          2612.490833                2
#
#     NumCreditCard  InterestRate  NumofLoan  Delayfromduedate  \
# 6               1             3          4                 3
# ...

# %%
def convert_to_numeric_or_nan(value):
    try:
        return float(value)
    except ValueError:
        if value == '__-333333333333333333333333333__':
            return np.nan
        else:
            return value

# Apply the custom function to convert numeric values and handle the specific non-numeric value
for column in df.columns:
    df[column] = df[column].apply(convert_to_numeric_or_nan)

# %%
columns_to_convert = ['Occupation',
 'CreditMix',
 'PaymentofMinAmount',
 'PaymentBehaviour',
 'CreditScore']

encoder = LabelEncoder()

for i in columns_to_convert:
    data[i] = encoder.fit_transform(data[i])

# %%
data.dtypes
# Out:
# Age                         int64
# Occupation                  int32
# AnnualIncome              float64
# MonthlyInhandSalary       float64
# NumBankAccounts             int64
# NumCreditCard               int64
# InterestRate                int64
# NumofLoan                   int64
# Delayfromduedate            int64
# NumofDelayedPayment       float64
# ChangedCreditLimit        float64
# NumCreditInquiries        float64
# CreditMix                   int32
# OutstandingDebt           float64
# CreditUtilizationRatio    float64
# CreditHitoryAge           float64
# PaymentofMinAmount          int32
# Amountinvestedmonthly     float64
# PaymentBehaviour            int32
# MonthlyBalance            float64
# CreditScore                 int32
# dtype: object

# %%
data.head()
# Out:
#     Age  Occupation  AnnualIncome  MonthlyInhandSalary  NumBankAccounts  \
# 6    23          12      19114.12          1824.843333                2
# 9    28          13      34847.84          3037.986667                1
# 12   28          13      34847.84          3037.986667                1
# 13   28          13      34847.84          3037.986667                2
# 15   28          13      34847.84          3037.986667                2
#
#     NumCreditCard  InterestRate  NumofLoan  Delayfromduedate  \
# 6               1             3          4                 3
# 9               1             6          1                 7
# 12              1             6          1                 3
# 13              1             6          1                 3
# 15              1             6          1                 3
#
#     NumofDelayedPayment  ChangedCreditLimit  NumCreditInquiries  CreditMix  \
# 6                   8.0               11.27                 4.0          1
# ...

# %%
data.shape
# Out:
# (39362, 21)

# %%
data.dtypes
# Out:
# Age                         int64
# Occupation                  int32
# AnnualIncome              float64
# MonthlyInhandSalary       float64
# NumBankAccounts             int64
# NumCreditCard               int64
# InterestRate                int64
# NumofLoan                   int64
# Delayfromduedate            int64
# NumofDelayedPayment       float64
# ChangedCreditLimit        float64
# NumCreditInquiries        float64
# CreditMix                   int32
# OutstandingDebt           float64
# CreditUtilizationRatio    float64
# CreditHitoryAge           float64
# PaymentofMinAmount          int32
# Amountinvestedmonthly     float64
# PaymentBehaviour            int32
# MonthlyBalance            float64
# CreditScore                 int32
# dtype: object

# %%
X = data.drop(columns='CreditScore')
y = data['CreditScore']

# %%
X.shape
# Out:
# (39362, 20)

# %%
from sklearn.preprocessing import MinMaxScaler

minmax = MinMaxScaler()
X = minmax.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression(random_state = 0, max_iter= 2000)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=2000, random_state=0)

# %%
y_pred = classifier.predict(X_test)
# print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

cm = confusion_matrix(y_test, y_pred)
print(cm)
print(f"\n accuracy: {round(accuracy_score(y_test, y_pred)*100,2)}%")
# Out:
# [[1073   29  989]
#  [ 213 1479 1708]
#  [ 724  878 4716]]
#
#  accuracy: 61.55%

# %%
data.sample(1)
# Out:
#        Age  Occupation  AnnualIncome  MonthlyInhandSalary  NumBankAccounts  \
# 23377   40           5      63461.28              5109.44                8
#
#        NumCreditCard  InterestRate  NumofLoan  Delayfromduedate  \
# 23377              7             6          4                 6
#
#        NumofDelayedPayment  ChangedCreditLimit  NumCreditInquiries  CreditMix  \
# 23377                 15.0               12.39                 5.0          2
#
#        OutstandingDebt  CreditUtilizationRatio  CreditHitoryAge  \
# 23377          1266.31               25.907566             11.5
#
#        PaymentofMinAmount  Amountinvestedmonthly  PaymentBehaviour  \
# 23377                   1                 70.251                 1
#
#        MonthlyBalance  CreditScore
# 23377      514.056034            2
